# %% [markdown]
# # Images as Grids of Pixels

# %% [markdown]
# ### Import resources

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline

# %% [markdown]
# ### Read in and display the image

# %%
#for image read
image = mpimg.imread('images/car.jpg')
#for dimension print
print('image dimenstion',image.shape)
# Out:
# image dimenstion (427, 640, 3)

# %%
#change from the color to grey scale
gray_image = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
plt.imshow(grey_image, cmap='gray')

# %%
#print specific grayscale pixel value
x = 190
y = 375
pixel_val = gray_image[y,x]
print(pixel_val)
# Out:
# 28
